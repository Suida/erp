# %%
from hello import ERGraph, Entity

# %%
person = Entity('person', ['id', 'name', 'age', 'gender',])
er = ERGraph(nodes=[person])
student = Entity('Student', ['id', 'school', 'class', 'score', 'person_id'])
er.node(student)
er.edge(student, person, 'person_id')
er

# %%
driver = Entity('Driver', ['truck_id', 'person_id'])

# %%
truck = Entity('Truck', ['plate_num', 'model'])

# %%
driver.edge_to(truck, 'truck_id')
driver.edge_to(person, 'person_id')

# %%
er.node(driver)
er.node(truck)

# %%
er

# %%
for each in er.body:
    print(each)
# Out:
# 	node [fontname="Cascadia Code" fontsize=10 shape=plaintext]
# 	person [label=<<table border="1" cellborder="0" cellspacing="0" cellpadding="2">
# 	<tr><td bgcolor="#cfcfcf" width="72" cellpadding="5" >Person</td></tr>
# 	<tr><td align="left"  port="id">  id</td></tr>
# 	<tr><td align="left"  port="name">  name</td></tr>
# 	<tr><td align="left"  port="age">  age</td></tr>
# 	<tr><td align="left"  port="gender">  gender</td></tr>
# </table>>]
# 	Student [label=<<table border="1" cellborder="0" cellspacing="0" cellpadding="2">
# 	<tr><td bgcolor="#cfcfcf" width="72" cellpadding="5" >Student</td></tr>
# 	<tr><td align="left"  port="id">  id</td></tr>
# 	<tr><td align="left"  port="school">  school</td></tr>
# 	<tr><td align="left"  port="class">  class</td></tr>
# 	<tr><td align="left"  port="score">  score</td></tr>
# 	<tr><td align="left"  port="person_id">  person_id</td></tr>
# </table>>]
# 	Student:person_id -> person
# 	Driver [label=<<table border="1" cellborder="0" cellspacing="0" cellpadding="2">
# 	<tr><td bgcolor="#cfcfcf" width="72" cellpadding="5" >Driver</td></tr>
# 	<tr><td align="left"  port="id">  id</td></tr>
# 	<tr><td align="left"  port="truck_id">  truck_id</td></tr>
# 	<tr><td align="left"  port="person_id">  person_id</td></tr>
# </table>>]
# 	Driver:person_id -> person
# 	Truck [label=<<table border="1" cellborder="0" cellspacing="0" cellpadding="2">
# 	<tr><td bgcolor="#cfcfcf" width="72" cellpadding="5" >Truck</td></tr>
# 	<tr><td align="left"  port="id">  id</td></tr>
# 	<tr><td align="left"  port="plate_num">  plate_num</td></tr>
# 	<tr><td align="left"  port="model">  model</td></tr>
# </table>>]
# 	Driver:truck_id -> Truck
